# %% [markdown]
# # set_index Basics

# %%
import pandas as pd

# %%
coin = pd.read_csv("C:/Matplotlib/DataAnalysis/data/coin_Bitcoin.csv")

coin

# %% [markdown]
# <!-- DataFrame.info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None)[source]
# Print a concise summary of a DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage. -->

# %%
coin.info()

# %%
coin

# %% [markdown]
# # Set the index to become the ‘’ column:

# %%
coin.set_index(["SNo"], inplace=True)

coin

# %%
coin = pd.read_csv("C:/Matplotlib/DataAnalysis/data/coin_Bitcoin.csv")
coin

# %%
coin.High.value_counts().head(10).plot()

# %% [markdown]
# # the world happiness report 2021 dataset

# %%
world = pd.read_csv("C:/Matplotlib/DataAnalysis/data/world-happiness-report-2021.csv")

world
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
world["Healthy life expectancy"].head(5).plot()

# %%
world.set_index(["Country name"], inplace=True)

# %%
world["Healthy life expectancy"].head(5).plot()

# %%
df = pd.read_csv("C:/Matplotlib/DataAnalysis/data/world-happiness-report-2021.csv", index_col=0)

df

# %% [markdown]
# # sort the values_intro
#
# this is ascending way it is sorted

# %%
world.sort_values("Healthy life expectancy" , ascending= False).head(10)

# %%
world.sort_values("Ladder score", ascending=False).head(10)

# %% [markdown]
# # Create a MultiIndex using columns ‘column name’ and ‘column name’:

# %%
world.sort_values(["Country name" ,"upperwhisker" ] , ascending=True)

# %% [markdown]
# # string values in the column

# %%
world.sort_values("Country name").head(20)

# %%
titanic = pd.read_csv("C:/Matplotlib/DataAnalysis/data/titanic.csv")

titanic
titanic.head(20)

# %% [markdown]
# # Sort values is wrong in the name column , capatilazed

# %%
titanic.sort_values('name')

# %%
titanic.sort_values("name" , key=lambda col :col.str.lower())

# %% [markdown]
# # A key function can be specified which is applied to the index before sorting. For a MultiIndex this is applied to each level separately.
#
# # df = pd.DataFrame({"a": [1, 2, 3, 4]}, index=['A', 'b', 'C', 'd'])
# # df.sort_index(key=lambda x: x.str.lower())
#    a
# A  1
# b  2
# C  3
# d  4

# %%
titanic.sort_values("name" , key=lambda col:col.str.lower())

# %% [markdown]
# # index_sort
#
# # The original DataFrame sorted by the labels or None

# %%
world.sort_index()

# %% [markdown]
# # By default, it sorts in ascending order, to sort in descending order, use -->

# %%
world.sort_index(ascending=False)

# %% [markdown]
# # Sorting and plotting

# %% [markdown]
# # The returned Series will have a MultiIndex with one level per input column but an Index (non-multi) for a single label. By default, rows that contain any NA values are omitted from the result. By default, the resulting Series will be in descending order so that the first element is the most frequently-occurring row.

# %%
titanic.pclass.value_counts()

# %%
titanic.pclass.value_counts().sort_values()

# %%
titanic.pclass.value_counts().sort_values().plot(kind="pie")

# %%
world["Regional indicator"].value_counts().plot(kind="bar")

# %%
world["Healthy life expectancy"].value_counts().plot(kind="hist")

# %%
houses = pd.read_csv("C:/Matplotlib/DataAnalysis/data/kc_house_data.csv")

# %%
houses.bedrooms.value_counts().plot(kind="bar")

# %%
houses.bedrooms.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# # LOC

# %%
world["Ladder score"]
# Out:
# 0      7.842
# 1      7.620
# 2      7.571
# 3      7.554
# 4      7.464
#        ...
# 144    3.512
# 145    3.467
# 146    3.415
# 147    3.145
# 148    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %% [markdown]
# # Slice with labels for row and single label for column. As mentioned above, note that both the start and stop of the slice are included.

# %%
world.loc[[0]]
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
# ...

# %%
world.set_index("Country name" , inplace=True)

# %%
world.loc["Finland"]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                           7.842
# Standard error of ladder score                         0.032
# upperwhisker                                           7.904
# lowerwhisker                                            7.78
# Logged GDP per capita                                 10.775
# Social support                                         0.954
# Healthy life expectancy                                 72.0
# Freedom to make life choices                           0.949
# Generosity                                            -0.098
# Perceptions of corruption                              0.186
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.446
# Explained by: Social support                           1.106
# Explained by: Healthy life expectancy                  0.741
# ...

# %%
world.loc[["Finland" , "Denmark" , "Switzerland"]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
# Denmark                0.954                     72.7
# Switzerland            0.942                     74.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# ...

# %%
titanic.loc[0]

# %%
titanic.loc[[0 , 7 ,8 , 9]]
# Out:
#    pclass  survived                                           name     sex  \
# 0       1         1                  Allen, Miss. Elisabeth Walton  female
# 7       1         0                         Andrews, Mr. Thomas Jr    male
# 8       1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                        Artagaveytia, Mr. Ramon    male
#
#   age  sibsp  parch    ticket      fare cabin embarked boat body  \
# 0  29      0      0     24160  211.3375    B5        S    2    ?
# 7  39      0      0    112050         0   A36        S    ?    ?
# 8  53      2      0     11769   51.4792  C101        S    D    ?
# 9  71      0      0  PC 17609   49.5042     ?        C    ?   22
#
#              home.dest
# 0         St Louis, MO
# 7          Belfast, NI
# 8  Bayside, Queens, NY
# 9  Montevideo, Uruguay

# %%
# titanic.loc[[5:10:2]]

# %%
world.sort_index(inplace=True)

world

# %%
world.set_index("Country name")

# %%
world.iloc[0:5:2]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Switzerland      Western Europe         7.571                           0.036
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904          7.78                 10.775
# Switzerland          7.643          7.50                 11.117
# Netherlands          7.518          7.41                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
# Switzerland            0.942                     74.4
# Netherlands            0.942                     72.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# ...

# %% [markdown]
# # Iloc

# %%
world.loc["Yemen"]

# %%
titanic.loc[5:10:2]
# Out:
#    pclass  survived                     name   sex age  sibsp  parch  \
# 5       1         1      Anderson, Mr. Harry  male  48      0      0
# 7       1         0   Andrews, Mr. Thomas Jr  male  39      0      0
# 9       1         0  Artagaveytia, Mr. Ramon  male  71      0      0
#
#      ticket     fare cabin embarked boat body            home.dest
# 5     19952    26.55   E12        S    3    ?         New York, NY
# 7    112050        0   A36        S    ?    ?          Belfast, NI
# 9  PC 17609  49.5042     ?        C    ?   22  Montevideo, Uruguay

# %%
world.sort_index(inplace=True)

# %%
world.loc["Denmark":"France" : 2]
# Out:
#                           Regional indicator  Ladder score  \
# Country name
# Denmark                       Western Europe         7.620
# Iceland                       Western Europe         7.554
# Norway                        Western Europe         7.392
# Luxembourg                    Western Europe         7.324
# Austria                       Western Europe         7.268
# Israel          Middle East and North Africa         7.157
# Canada                 North America and ANZ         7.103
# Costa Rica       Latin America and Caribbean         7.069
# Czech Republic    Central and Eastern Europe         6.965
# Belgium                       Western Europe         6.834
#
#                 Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Denmark                                  0.035         7.687         7.552
# Iceland                                  0.059         7.670         7.438
# ...

# %% [markdown]
# # iloc
#
# # Purely integer-location based indexing for selection by position.

# %%
world.iloc[20]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
coin.iloc[[0]]
# Out:
#    SNo     Name Symbol                 Date        High    Low     Open  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.0  134.444
#
#         Close  Volume     Marketcap
# 0  144.539993     0.0  1.603769e+09

# %%
coin.iloc[[10,20,30,40]]
# Out:
#     SNo     Name Symbol                 Date        High         Low  \
# 10   11  Bitcoin    BTC  2013-05-09 23:59:59  113.459999  109.260002
# 20   21  Bitcoin    BTC  2013-05-19 23:59:59  124.500000  119.570999
# 30   31  Bitcoin    BTC  2013-05-29 23:59:59  132.589996  127.662003
# 40   41  Bitcoin    BTC  2013-06-08 23:59:59  111.415001  107.300003
#
#           Open       Close  Volume     Marketcap
# 10  113.199997  112.669998     0.0  1.254535e+09
# 20  123.210999  121.989998     0.0  1.363205e+09
# 30  129.000000  132.300003     0.0  1.483735e+09
# 40  111.000000  108.300003     0.0  1.219718e+09

# %%
coin.iloc[50:60]
# Out:
#     SNo     Name Symbol                 Date        High         Low  \
# 50   51  Bitcoin    BTC  2013-06-18 23:59:59  111.111000  101.032997
# 51   52  Bitcoin    BTC  2013-06-19 23:59:59  110.224998  105.754997
# 52   53  Bitcoin    BTC  2013-06-20 23:59:59  114.300003  107.500000
# 53   54  Bitcoin    BTC  2013-06-21 23:59:59  114.989998  107.684998
# 54   55  Bitcoin    BTC  2013-06-22 23:59:59  109.956001  107.514000
# 55   56  Bitcoin    BTC  2013-06-23 23:59:59  108.800003  106.234001
# 56   57  Bitcoin    BTC  2013-06-24 23:59:59  108.334000  100.980003
# 57   58  Bitcoin    BTC  2013-06-25 23:59:59  106.470001  101.010002
# 58   59  Bitcoin    BTC  2013-06-26 23:59:59  105.488998  102.792000
# 59   60  Bitcoin    BTC  2013-06-27 23:59:59  104.000000  101.099998
#
#           Open       Close  Volume     Marketcap
# 50  101.949997  107.400002     0.0  1.214216e+09
# 51  107.050003  108.250000     0.0  1.224194e+09
# 52  108.250999  110.150002     0.0  1.246105e+09
# ...

# %%
titanic.iloc[0:5]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.loc[108:109]

# %% [markdown]
# # loc & iloc with series

# %%
world.sort_index(ascending=False , inplace=True)

# %%
world
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
world.loc[148: 130, ["Country name" , "Ladder score"]]
# Out:
# Empty DataFrame
# Columns: [Country name, Ladder score]
# Index: []

# %%
world.loc[148:1:2, ["Country name" , "Ladder score"]]

# %%
world.set_index("Country name" , inplace=True)

# %%
world.sort_values("Country name" , ascending=True)

# %%
world.loc["Afghanistan" :"Armenia" ]["Ladder score"]

# %%
world.loc["Afghanistan" :"Armenia" , ["Ladder score"]]

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses["bedrooms"].value_counts().iloc[0]
# Out:
# 9824

# %%
houses["bedrooms"].value_counts().iloc[0:3]
# Out:
# bedrooms
# 3    9824
# 4    6882
# 2    2760
# Name: count, dtype: int64

# %%
houses["bedrooms"].value_counts().loc[33]

# %%
titanic["age"].value_counts().loc["18"]
# Out:
# age
# ?         263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic["age"].value_counts().iloc[0:5]
# Out:
# age
# ?     263
# 24     47
# 22     43
# 21     41
# 30     40
# Name: count, dtype: int64

# %% [markdown]
# #

# %%
world
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# # we want alternative values columns wise -->

# %%
world.loc[ :,"Country name": :2]
# Out:
#     Country name  Ladder score  upperwhisker  Logged GDP per capita  \
# 0        Finland         7.842         7.904                 10.775
# 1        Denmark         7.620         7.687                 10.933
# 2    Switzerland         7.571         7.643                 11.117
# 3        Iceland         7.554         7.670                 10.878
# 4    Netherlands         7.464         7.518                 10.932
# ..           ...           ...           ...                    ...
# 144      Lesotho         3.512         3.748                  7.926
# 145     Botswana         3.467         3.611                  9.782
# 146       Rwanda         3.415         3.548                  7.676
# 147     Zimbabwe         3.145         3.259                  7.943
# 148  Afghanistan         2.523         2.596                  7.695
#
#      Healthy life expectancy  Generosity  Ladder score in Dystopia  \
# 0                     72.000      -0.098                      2.43
# ...
