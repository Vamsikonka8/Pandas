# %%
import pandas as pd

# %% [markdown]
# # min(), max(), mean(), median(), count(), sum(), describe

# %%
titanic = pd.read_csv("C:/Matplotlib/DataAnalysis/data/titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses = pd.read_csv("C:/Matplotlib/DataAnalysis/data/countries of the world.csv")

houses

# %% [markdown]
# # It give minimum values in the table only numeric values

# %%
houses.min(numeric_only=True)

# %%
titanic.max(numeric_only=True)

# %% [markdown]
# # it is gives the top 10 rows using a head method gives top 5 rows

# %%
titanic.head(10)

# %%
titanic.sum(numeric_only=True)

# %% [markdown]
# # it gives the last 5 rows as  defalut tail method , if i can  more phase inside the parenthesis

# %%
houses.tail()

# %% [markdown]
# # combining two methods and do aggregation menthod sum ()method

# %%
state_pops = pd.read_csv("C:/Matplotlib/DataAnalysis/data/state_pops.csv")

state_pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
houses.tail(2).head(2).sum()

# %% [markdown]
# # count method it is count number of rows in the table

# %%
titanic.count(numeric_only=True)

# %% [markdown]
# # mean , median , mode () method

# %% [markdown]
# # the mean is the average or norm

# %%
type(houses.mean(numeric_only=True))

# %%
house1 = pd.read_csv("C:/Matplotlib/DataAnalysis/data/kc_house_data.csv")
house1.sum()

# %% [markdown]
# # the median is the middle value

# %%
house1.median(numeric_only=True)

# %%
titanic.mean(numeric_only=True)

# %% [markdown]
# # the mode is the most frequent value

# %%
titanic.mode(numeric_only=True)

# %% [markdown]
# # it describe the table what are there in the table , all things

# %%
house1.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# # it is the describe the  numeric values you just call the method

# %%
titanic.describe(include=["object"])
# Out:
#                         name   sex   age    ticket  fare cabin embarked  boat  \
# count                   1309  1309  1309      1309  1309  1309     1309  1309
# unique                  1307     2    99       929   282   187        4    28
# top     Connolly, Miss. Kate  male     ?  CA. 2343  8.05     ?        S     ?
# freq                       2   843   263        11    60  1014      914   823
#
#         body home.dest
# count   1309      1309
# unique   122       370
# top        ?         ?
# freq    1188       564

# %%
houses.describe(include=["O"])
# Out:
#              Country                               Region  \
# count            227                                  227
# unique           227                                   11
# top     Afghanistan   SUB-SAHARAN AFRICA
# freq               1                                   51
#
#        Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# count                         227                          227           224
# unique                        219                          151           157
# top                          66,6                         0,00             0
# freq                            2                           44            62
#
#        Infant mortality (per 1000 births) Literacy (%) Phones (per 1000)  \
# count                                 224          209               223
# unique                                220          140               214
# top                                  9,95         99,0             269,5
# ...

# %% [markdown]
# # Execise Question and answers

# %% [markdown]
# # find the lower user rating in the Df

# %%
bestseller = pd.read_csv("C:/Matplotlib/DataAnalysis/data/bestsellers.csv")
bestseller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestseller.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %% [markdown]
# # Find the highest price in the Df

# %%
bestseller.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %% [markdown]
# # what is the average user rating

# %%
bestseller.mean(numeric_only=True)
# Out:
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %% [markdown]
# # what is the average user rating of the first 5 rows

# %%
bestseller.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# # what user review score appeared the most

# %%
bestseller.mode(numeric_only=True)
# Out:
#     User Rating  Reviews  Price  Year
# 0           4.8   8580.0    8.0  2009
# 1           NaN      NaN    NaN  2010
# 2           NaN      NaN    NaN  2011
# 3           NaN      NaN    NaN  2012
# 4           NaN      NaN    NaN  2013
# 5           NaN      NaN    NaN  2014
# 6           NaN      NaN    NaN  2015
# 7           NaN      NaN    NaN  2016
# 8           NaN      NaN    NaN  2017
# 9           NaN      NaN    NaN  2018
# 10          NaN      NaN    NaN  2019

# %% [markdown]
# # what is the total(sum) of the all the values in the reviews column

# %%
bestseller.sum(numeric_only=True)
# Out:
# User Rating       2540.1
# Reviews        6574305.0
# Price             7205.0
# Year           1107700.0
# dtype: float64

# %% [markdown]
# # How many different authors are featured in the dataset

# %%
bestseller.describe(include=["object"])
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %% [markdown]
# # Which author wrote the most member of tooks on the list how many did they write

# %%
bestseller.describe(include=["O"])
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %%
titanic.pc
