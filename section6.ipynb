# %%
import pandas as pd

# %%
crime = pd.read_csv("C:/Matplotlib/DataAnalysis/data/crime.csv")
crime

# %%
band = pd.read_csv("C:/Matplotlib/DataAnalysis/data/bands.csv")

mount_everest = pd.read_csv("C:/Matplotlib/DataAnalysis/data/mount_everest_deaths.csv")

salaries = pd.read_csv("C:/Matplotlib/DataAnalysis/data/Salaries.csv")

salaries
# Out:
# C:\Users\konka vamsi\AppData\Local\Temp\ipykernel_17356\1641110213.py:5: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salaries = pd.read_csv("C:/Matplotlib/DataAnalysis/data/Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# # if i want a single column by the table using a like this function

# %%
band.name

# %% [markdown]
# # Example is a band.age ---> dot notation function is a not most of situation will not work
#
# # band["age"] ---> this is the work instead of above the problem

# %%
band["name"]

# %%
mystery_col =

# %%
salaries[mystery_col]

# %% [markdown]
# # What is the series
#
# # one - dimensional ndarray with axis labels

# %%
titanic = band.name

type(titanic)

# %%
band.mean(numeric_only=True)

# %%
salaries.sum(numeric_only=True)

# %% [markdown]
# # this is the given single values in sum method in the result set

# %%
salaries.TotalPayBenefits.sum()

# %%
salaries.max(numeric_only=True)

# %% [markdown]
# # it is gives the single column numeric typr max price

# %%
salaries.TotalPayBenefits.max(numeric_only=True)

# %%
salaries.shape

# %% [markdown]
# # this is the code the defines variable name values is the table

# %%
titanic.shape

# %% [markdown]
# # this is the values of the table

# %%
band.values

# %% [markdown]
# # index function as show like what is the range of the table

# %%
salaries.index

# %%
salaries

# %% [markdown]
# # do you understand is the min column name gives the index function and values function min values

# %%
mins = salaries.min(numeric_only=True)

mins.index

# %%
mins.values

# %% [markdown]
# # One dimensional structure instead of multiple dimensional structure

# %% [markdown]
# # Important series Method
#
# > head()
# > tail()
# > describe()
# > unique()
# > nunique()
# > nlargest()
# > nsmallest()
# > value_counts()

# %%
mount_everest

# %%
mount_everest.Age.head(10)

# %% [markdown]
# # salaries is the particular certain number of the values gives then min values amd median

# %%
salaries.TotalPayBenefits.tail(5)

# %% [markdown]
# # describe the values of the table and particular column
#
# it is gives the describe the table

# %%
salaries.describe()

# %% [markdown]
# # particular column describe all of things

# %%
salaries

# %%
salaries["TotalPayBenefits"].describe()

# %%
salaries[["JobTitle", "EmployeeName"]].describe(include=["O"])

# %% [markdown]
# # What are the datatype and column table information in the table

# %%
salaries.info()

# %%
mount_everest.info()

# %%
band.info(["O"])

# %% [markdown]
# # above given info method instead of this one also dtype those are similar

# %%
band.select_dtypes(include=["O"])

# %% [markdown]
# # Unique & Nunique
#
#
# mount_everest.unique() it gives the error doesn't using this like method

# %%
mount_everest.unique()

# %%
mount_everest

# %% [markdown]
# # it is the  unique values in that column
#
# Return unique values of Series object.

# %%
mount_everest["Name"].unique()

# %% [markdown]
# # Series.nunique(dropna=True)[source]
# Return number of unique elements in the object.
#
# Excludes NA values by default. -->

# %%
band.genre.unique()

# %% [markdown]
# # Return number of unique elements in the object.
#
# Excludes NA values by default.

# %%
mount_everest["Name"].nunique()
# Out:
# 303

# %% [markdown]
# nlargest , nsmallest
#
# Series.nlargest(n=5, keep='first')[source]
# Return the largest n elements.

# %%
salaries.TotalPayBenefits.nlargest(5, keep="all")
# Out:
# 0         567595.43
# 1         538909.28
# 110531    510732.68
# 110532    479652.21
# 110533    436224.36
# Name: TotalPayBenefits, dtype: float64

# %%
titanic = pd.read_csv("C:/Matplotlib/DataAnalysis/data/titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses = pd.read_csv("C:/Matplotlib/DataAnalysis/data/kc_house_data.csv")

houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.nlargest(10 , ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.nlargest(10, ["bedrooms" , "bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %% [markdown]
#  # selecting the multiple columns

# %% [markdown]
# # how to select more than a one column
#
# it is the nested a array

# %%
band[["genre", "id", "theme"]]
# Out:
#                                                    genre     id  \
# 0                                            Death Metal      1
# 1                                            Death Metal      2
# 2                                            Death Metal      3
# 3                                            Death Metal      4
# 4                                            Death Metal      5
# ...                                                  ...    ...
# 37718  Death/Thrash Metal (1988-93)| Grunge/Hard Rock...  37719
# 37719  Post-Rock (early)| Progressive Death Metal (mi...  37720
# 37720  Black/Death/Doom Metal (early)| Drone/Dark Amb...  37721
# 37721  Progressive Thrash/Death Metal (1992| 2002-pre...  37722
# 37722  Gothic Metal (2004-2006)| Melodic Death/Gothic...  37723
#
#                                                   theme
# 0                                                   NaN
# 1                                                   NaN
# ...

# %%
mount_everest[["Cause of death", "Age", "Name"]].tail(10)
# Out:
#                        Cause of death   Age                    Name
# 300             Exhaustion on descent  54.0       Anjali S Kulkarni
# 301             Exhaustion on descent  52.0            Kalpana Dash
# 302                 Altitude sickness  56.0             Kevin Hynes
# 303  Exhaustion and altitude sickness   NaN            Dhruba Bista
# 304         Exhaustion during descent  44.0     Robin Haynes Fisher
# 305      Cardiac event during descent  62.0  Christopher Jon Kulish
# 306                        Exhaustion  55.0               Puwei Liu
# 307                        Exhaustion  41.0           Abdul Waraich
# 308              Fall into a crevasse  28.0      Pemba Tashi Sherpa
# 309                               NaN   NaN      Wong Dorchi Sherpa

# %%
mount_everest[["Cause of death", "Age", "Name"]].describe()
# Out:
#               Age
# count  160.000000
# mean    40.356250
# std     12.244545
# min     19.000000
# 25%     31.750000
# 50%     38.000000
# 75%     48.000000
# max     85.000000

# %%
cols = ["Cause of death", "Age", "Name"]

mount_everest[cols]
# Out:
#                    Cause of death   Age                    Name
# 0                       Avalanche   NaN                   Dorje
# 1                       Avalanche   NaN                  Lhakpa
# 2                       Avalanche   NaN                   Norbu
# 3                       Avalanche   NaN                  Pasang
# 4                       Avalanche   NaN                    Pema
# ..                            ...   ...                     ...
# 305  Cardiac event during descent  62.0  Christopher Jon Kulish
# 306                    Exhaustion  55.0               Puwei Liu
# 307                    Exhaustion  41.0           Abdul Waraich
# 308          Fall into a crevasse  28.0      Pemba Tashi Sherpa
# 309                           NaN   NaN      Wong Dorchi Sherpa
#
# [310 rows x 3 columns]

# %% [markdown]
# band

# %%
band["genre"].value_counts()
# Out:
# genre
# Death Metal                                                                                    9621
# Melodic Death Metal                                                                            2866
# Death/Thrash Metal                                                                             2709
# Brutal Death Metal                                                                             2215
# Black/Death Metal                                                                              2033
#                                                                                                ...
# Death/Stoner/Doom Metal                                                                           1
# Symphonic Folk/Celtic Death Metal                                                                 1
# Blackened Death Metal/Drone                                                                       1
# ...

# %%
mount_everest["Age"].value_counts()
# Out:
# Age
# 28.0    10
# 33.0    10
# 35.0     9
# 27.0     8
# 50.0     6
# 36.0     6
# 55.0     6
# 34.0     6
# 37.0     6
# 44.0     6
# 43.0     5
# 41.0     5
# 38.0     5
# 45.0     4
# 22.0     4
# 31.0     4
# 40.0     4
# 48.0     4
# 46.0     3
# 63.0     3
# 54.0     3
# 30.0     3
# 39.0     3
# 62.0     3
# 47.0     3
# 23.0     2
# 29.0     2
# 56.0     2
# 58.0     2
# 61.0     2
# 25.0     2
# 52.0     2
# 42.0     2
# 49.0     2
# 82.0     1
# 19.0     1
# 85.0     1
# 21.0     1
# 69.0     1
# 24.0     1
# 53.0     1
# 66.0     1
# 32.0     1
# 51.0     1
# 26.0     1
# 20.0     1
# 65.0     1
# Name: count, dtype: int64

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
band.name.value_counts().head(10)
# Out:
# name
# Mortuary        23
# Necrosis        20
# Necropsy        19
# Legion          17
# Decay           15
# Infected        14
# Putrefaction    14
# Abaddon         13
# Bloodshed       13
# Sickness        13
# Name: count, dtype: int64

# %% [markdown]
# # Each value How many type appears

# %%
band.name.value_counts(ascending=True)
# Out:
# name
# ('M') Inc.            1
# Plutocracy            1
# Plunder & Pillage     1
# Plough                1
# Plenty of Nails       1
#                      ..
# Decay                15
# Legion               17
# Necropsy             19
# Necrosis             20
# Mortuary             23
# Name: count, Length: 33035, dtype: int64

# %%
mount_everest[["Name", "Nationality", "Age"]].value_counts()
# Out:
# Name                    Nationality     Age
# Abdul Waraich           Switzerland     41.0    1
# Akira Ube               Japan           31.0    1
# Pascal Debrouwer        Belgium         29.0    1
# Pemba Sherpa            Nepal           19.0    1
# Pemba Tashi Sherpa      Nepal           28.0    1
#                                                ..
# Joon-ho Baek            South Korea     38.0    1
# Jozef Just              Czechoslovakia  33.0    1
# Jozef Psotka            Czechoslovakia  50.0    1
# Juan José Polo Carbayo  Spain           43.0    1
# Yoshitomi Okura         Japan           62.0    1
# Name: count, Length: 160, dtype: int64

# %% [markdown]
# # using plot Visualization

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df = houses[["bedrooms", "bathrooms"]]

# df.plot(x="bedrooms", y="bathrooms")

# scatter.plot()

df.plot(kind="scatter", x = "bedrooms", y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
df = salaries[["id", "Year"]]
df.plot(x="id", y="Year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Matplotlib\DataAnalysis\Jupyter files\section6.ipynb Cell 80 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Matplotlib/DataAnalysis/Jupyter%20files/section6.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> df = salaries[["id", "Year"]]
#       <a href='vscode-notebook-cell:/c%3A/Matplotlib/DataAnalysis/Jupyter%20files/section6.ipynb#Y152sZmlsZQ%3D%3D?line=1'>2</a> df.plot(x="id", y="Year")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
titanic[["pclass", "name"]].plot()
# Out:
# <Axes: >

# %%
houses.plot()
# Out:
# <Axes: >

# %%
salaries.TotalPayBenefits.value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='TotalPayBenefits'>

# %%
titanic.survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
band.genre.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
mount_everest.Nationality.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Nationality'>

# %%
houses.bedrooms.value_counts().plot()
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.plot()
# Out:
# <Axes: >

# %%
bestsellers = pd.read_csv("C:/Matplotlib/DataAnalysis/data/bestsellers.csv")

bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestsellers.
